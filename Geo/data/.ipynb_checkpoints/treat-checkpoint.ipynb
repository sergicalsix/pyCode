# %%
import pandas as pd
df_population = pd.read_csv('population.csv', encoding='sjis')
df_population
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                   00    全国   大正    9.0
# 1                                                   01   北海道   大正    9.0
# 2                                                   02   青森県   大正    9.0
# 3                                                   03   岩手県   大正    9.0
# 4                                                   04   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
df_population = df_population[df_population['西暦（年）'] == 2015]
df_population
# Out:
#     都道府県コード        都道府県名  元号  和暦（年）   西暦（年）    注     人口（総数）     人口（男）  \
# 930      00           全国  平成   27.0  2015.0  NaN  127094745  61841738
# 931      0A       人口集中地区  平成   27.0  2015.0  NaN   86868176  42363423
# 932      0B  人口集中地区以外の地区  平成   27.0  2015.0  NaN   40226569  19478315
# 933      01          北海道  平成   27.0  2015.0  NaN    5381733   2537089
# 934      02          青森県  平成   27.0  2015.0  NaN    1308265    614694
# 935      03          岩手県  平成   27.0  2015.0  NaN    1279594    615584
# 936      04          宮城県  平成   27.0  2015.0  NaN    2333899   1140167
# 937      05          秋田県  平成   27.0  2015.0  NaN    1023119    480336
# 938      06          山形県  平成   27.0  2015.0  NaN    1123891    540226
# 939      07          福島県  平成   27.0  2015.0  NaN    1914039    945660
# 940      08          茨城県  平成   27.0  2015.0  NaN    2916976   1453594
# 941      09          栃木県  平成   27.0  2015.0  NaN    1974255    981626
# ...

# %%
df_population = df_population[3:]
df_population
# Out:
#     都道府県コード 都道府県名  元号  和暦（年）   西暦（年）    注    人口（総数）    人口（男）    人口（女）
# 933      01   北海道  平成   27.0  2015.0  NaN   5381733  2537089  2844644
# 934      02   青森県  平成   27.0  2015.0  NaN   1308265   614694   693571
# 935      03   岩手県  平成   27.0  2015.0  NaN   1279594   615584   664010
# 936      04   宮城県  平成   27.0  2015.0  NaN   2333899  1140167  1193732
# 937      05   秋田県  平成   27.0  2015.0  NaN   1023119   480336   542783
# 938      06   山形県  平成   27.0  2015.0  NaN   1123891   540226   583665
# 939      07   福島県  平成   27.0  2015.0  NaN   1914039   945660   968379
# 940      08   茨城県  平成   27.0  2015.0  NaN   2916976  1453594  1463382
# 941      09   栃木県  平成   27.0  2015.0  NaN   1974255   981626   992629
# 942      10   群馬県  平成   27.0  2015.0  NaN   1973115   973283   999832
# 943      11   埼玉県  平成   27.0  2015.0  NaN   7266534  3628418  3638116
# 944      12   千葉県  平成   27.0  2015.0  NaN   6222666  3095860  3126806
# ...

# %%
#df_population = df_population[['都道府県コード','人口（総数）']]
df_population.columns = ['prefecture_code','population']
df_population = df_population.astype({'prefecture_code': int, 'population': int})

# %%
df_population.to_csv('population_done.csv',header = False)

# %% [markdown]
# # vaccine

# %%
df_vaccine = pd.read_json('prefecture.ndjson',lines = True)
df_vaccine = df_vaccine[['date','prefecture','count']]

# %%
df_vaccine
# Out:
#             date  prefecture  count
# 0     2021-04-12           1    116
# 1     2021-04-12           1     89
# 2     2021-04-12           1     39
# 3     2021-04-12           1     26
# 4     2021-04-12           1     12
# ...          ...         ...    ...
# 41463 2021-07-21          47    265
# 41464 2021-07-21          47    143
# 41465 2021-07-21          47    619
# 41466 2021-07-21          47     10
# 41467 2021-07-21          47      4
#
# [41468 rows x 3 columns]

# %%
df_vaccine.to_csv('vaccine.csv')
